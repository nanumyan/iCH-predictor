# %%
rgb = np.loadtxt('out/RGBcolors.txt', delimiter='\t')

# %%
prey = rgb[11,0]
col1 = rgb[11,1:4]

# %%
prey
# Out:
# 120282.0

# %%
preys = rgb[:20,0]

s = ''
for i in preys:
    s = ' '.join([s, '%i'%i])
print s
# Out:
#  128282 119382 43905 126329 130191 117098 128402 53759 129770 65946 119016 120282 101630 92432 50114 129272 101040 36484 88429 89487

# %%
from IPython.display import Image
Image(filename='images/%i.jpg'%preys[17], format=u'jpeg')

# %%
figure(figsize=(17,10))
for i, cols in enumerate(rgb[:20,1:]):
    ax = plt.subplot(2,10,i+1)
    ax.scatter(repeat(1,3),range(3), s=1e4, c=map(tuple, cols.reshape((3,3))/255))
# plt.tight_layout()
