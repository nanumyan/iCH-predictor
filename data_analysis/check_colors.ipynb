# %%
rgb = np.loadtxt('RGB10colors.txt', delimiter='\t')

# %%
prey = rgb[11,0]
col1 = rgb[11,1:4]

# %%
import os
images = os.listdir('images')
images[:10]
# Out:
# ['100085',
#  '100086',
#  '100088',
#  '100093',
#  '100094',
#  '100095',
#  '100164',
#  '100165',
#  '100166',
#  '100167']

# %%
preys = rgb[:10,0]

s = ''
for i in preys:
    s = ' '.join([s, '%i'%i])
print s
# Out:
#  100173 100889 100926 100809 100923 100891 100085 100668 100347 100667

# %%
# from IPython.display import Image
# Image(filename='images/%i.jpg'%preys[17], format=u'jpeg')

# %%
figure(figsize=(17,5))
for i, cols in enumerate(rgb[30:40,1:]):
    ax = plt.subplot(1,10,i+1)
    ax.scatter(repeat(1,10),range(10), s=9e3, c=map(tuple, cols.reshape((10,3))/255))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
# plt.tight_layout()

# %%
map(tuple, rgb[1, 1:].reshape((10,3)))
# Out:
# [(130.0, 125.0, 109.0),
#  (194.0, 188.0, 178.0),
#  (235.0, 228.0, 220.0),
#  (177.0, 164.0, 144.0),
#  (177.0, 50.0, 52.0),
#  (21.0, 24.0, 26.0),
#  (83.0, 89.0, 79.0),
#  (196.0, 146.0, 104.0),
#  (85.0, 39.0, 37.0),
#  (217.0, 191.0, 160.0)]

# %%
rgb[1, 1:]
# Out:
# array([  25.,  155.,  108.,   71.,   72.,   68.,   34.,   40.,   37.,
#          88.,   91.,   85.,   11.,   12.,   11.,   53.,   56.,   52.,
#          58.,   39.,   10.,  155.,  155.,  154.,   99.,   74.,   27.,
#         131.,  102.,   45.])
